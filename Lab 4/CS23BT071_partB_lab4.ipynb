# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df_train1= pd.read_csv('WDBC_Train.csv')
df_train = df_train1.iloc[:, 1:]
print(df_train)
X = df_train.iloc[:, :-1]
y = df_train.iloc[:, -1]

print(y)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0         14.780         23.94           97.40      668.3          0.11720
# 1          9.667         18.49           61.49      289.1          0.08946
# 2         14.640         16.85           94.21      666.0          0.08641
# 3         19.550         23.21          128.90     1174.0          0.10100
# 4         12.270         29.97           77.42      465.4          0.07699
# ..           ...           ...             ...        ...              ...
# 336        9.720         18.22           60.73      288.1          0.06950
# 337       13.030         18.42           82.61      523.8          0.08983
# 338       11.890         21.17           76.39      433.8          0.09773
# 339       13.000         25.13           82.61      520.2          0.08369
# 340       14.200         20.53           92.41      618.4          0.08931
#
# ...

# %%
pd.DataFrame([X.mean(), X.std()], index=['Mean', 'Std. dev'])
# Out:
#           radius_mean  texture_mean  perimeter_mean   area_mean  \
# Mean        14.107827     19.583636       91.724311  652.242522
# Std. dev     3.490660      4.355908       23.960088  344.612598
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# Mean             0.095864          0.101609        0.086078
# Std. dev         0.014470          0.052701        0.079273
#
#           concave_points_mean  symmetry_mean  fractal_dimension_mean  ...  \
# Mean                 0.047949       0.181541                0.062561  ...
# Std. dev             0.038237       0.027555                0.007251  ...
#
#           radius_worst  texture_worst  perimeter_worst  area_worst  \
# Mean         16.235906      26.061466       106.796100  873.151320
# Std. dev      4.723132       6.161684        32.652081  546.229578
#
#           smoothness_worst  compactness_worst  concavity_worst  \
# Mean              0.131616           0.246855         0.265442
# ...

# %%
features = X.columns[0:]
print(features)
# Out:
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave_points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave_points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave_points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
scaler = StandardScaler()
X_standardized = pd.DataFrame(scaler.fit_transform(X))
X_standardized.columns=X.columns
X_standardized['diagnosis'] = y
print(X_standardized)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.192846      1.001574        0.237229   0.046664         1.476600
# 1      -1.274072     -0.251439       -1.263716  -1.055319        -0.443240
# 2       0.152680     -0.628492        0.103895   0.039980        -0.654325
# 3       1.561358      0.833740        1.553847   1.516266         0.355424
# 4      -0.527272      2.387935       -0.597883  -0.542978        -1.306268
# ..           ...           ...             ...        ...              ...
# 336    -1.258866     -0.313515       -1.295482  -1.058225        -1.824639
# 337    -0.309228     -0.267532       -0.380955  -0.373263        -0.417633
# 338    -0.636294      0.364722       -0.640934  -0.634810         0.129113
# 339    -0.317835      1.275168       -0.380955  -0.383725        -0.842572
# 340     0.026444      0.217579        0.028660  -0.098349        -0.453621
#
# ...

# %%
X_standardized.to_csv('WDBC_Scaled_Train.csv')

# %%
val1=pd.read_csv('WDBC_Validation.csv')
test1=pd.read_csv('WDBC_Test.csv')

val = val1.iloc[:, 1:]

val_X = val.iloc[:, :-1]
val_y = val.iloc[:, -1]


val_X_standardized = pd.DataFrame(scaler.transform(val_X))
val_X_standardized.columns=X.columns
val_X_standardized['diagnosis'] = val_y
print(val_X_standardized)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0      -0.558831     -0.357198       -0.561519  -0.572329        -0.345656
# 1      -0.398167     -1.334318       -0.415646  -0.465386         0.055752
# 2      -1.269482     -0.056015       -1.282107  -1.065199        -0.758138
# 3      -0.699412      0.100325       -0.690255  -0.685957         0.396949
# 4      -0.403905     -1.704474       -0.453264  -0.456958        -0.554665
# ..           ...           ...             ...        ...              ...
# 109     1.529799     -0.175568        1.520409   1.495923         0.902170
# 110    -0.065364     -0.787130       -0.140201  -0.161701        -1.772040
# 111     0.201453     -1.122800        0.122704   0.082700        -0.771288
# 112    -0.587521     -0.157175       -0.629649  -0.601390        -0.830807
# 113    -0.544486     -1.263045       -0.541039  -0.552859        -1.023206
#
# ...

# %%
test_X = test.iloc[:, :-1]
test_y = test.iloc[:, -1]


test_X_standardized = pd.DataFrame(scaler.transform(test_X))
test_X_standardized.columns=X.columns
test_X_standardized['diagnosis'] = test_y
print(test_X_standardized)
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0      -0.604735     -0.904385       -0.617528  -0.607202         0.094509
# 1       0.112514     -1.998759        0.106821  -0.033543         0.985221
# 2      -0.501451     -0.239943       -0.531425  -0.539200        -0.767827
# 3      -0.774006     -1.072220       -0.760475  -0.727223        -0.365034
# 4      -0.294883     -0.890590       -0.254726  -0.384306         0.805279
# ..           ...           ...             ...        ...              ...
# 109    -0.481368     -0.594005       -0.548562  -0.508396        -1.404544
# 110    -0.624818      0.447490       -0.635083  -0.620861         0.125653
# 111     0.121121     -0.056015        0.105567   0.021672        -0.829423
# 112    -0.352263      2.146529       -0.385552  -0.400871        -1.012825
# 113     0.241619     -0.187064        0.255620   0.108273        -1.002443
#
# ...

# %%
test_X_standardized.to_csv('WDBC_Scaled_Test.csv')
val_X_standardized.to_csv('WDBC_Scaled_Validation.csv')
