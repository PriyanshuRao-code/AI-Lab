# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler

df = pd.read_csv('winequality_red_original.csv')

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('fixed_acidity')
plt.ylabel('value')
plt.boxplot(df["fixed_acidity"])

fig2 = plt.figure(figsize =(2, 5))
plt.xlabel('volatile_acidity')
plt.ylabel('value')
plt.boxplot(df["volatile_acidity"])

fig3 = plt.figure(figsize =(2, 5))
plt.xlabel('citric_acid')
plt.ylabel('value')
plt.boxplot(df["citric_acid"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('residual_sugar')
plt.ylabel('value')
plt.boxplot(df["residual_sugar"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('chlorides')
plt.ylabel('value')
plt.boxplot(df["chlorides"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('free_sulfur_dioxide')
plt.ylabel('value')
plt.boxplot(df["free_sulfur_dioxide"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('total_sulfur_dioxide')
plt.ylabel('value')
plt.boxplot(df["total_sulfur_dioxide"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('density')
plt.ylabel('value')
plt.boxplot(df["density"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('pH')
plt.ylabel('value')
plt.boxplot(df["pH"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('sulphates')
plt.ylabel('value')
plt.boxplot(df["sulphates"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('alcohol')
plt.ylabel('value')
plt.boxplot(df["alcohol"])

plt.show()

# %%
selected_columns=df.iloc[:,0:13]
print(selected_columns)

Q1 = selected_columns.quantile(0.25)
Q3 = selected_columns.quantile(0.75)

IR = Q3-Q1
lower_bound=Q1-1.5*IR
upper_bound=Q3+1.5*IR

for column in selected_columns.columns:
    outliers=(selected_columns[column] < lower_bound[column]) | (selected_columns[column] > upper_bound[column])
    # print(selected_columns[column][outliers])
    print(f"Outliers in {column}-{outliers.sum()}")
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
for column in selected_columns.columns:
    outliers=(selected_columns[column] < lower_bound[column]) | (selected_columns[column] > upper_bound[column])
    selected_columns[column][outliers]=selected_columns[column].median()

selected_columns.to_csv('winequality_red_corrected.csv')
new1=pd.read_csv('winequality_red_corrected.csv')
new=new1.iloc[:,1:13]
Q1 = new.quantile(0.25)
Q3 = new.quantile(0.75)

IR = Q3-Q1
lower_bound=Q1-1.5*IR
upper_bound=Q3+1.5*IR

for column in new.columns:
    outliers1=(new[column] < lower_bound[column]) | (new[column] > upper_bound[column])
    # print(selected_columns[column][outliers])
    print(f"Outliers in {column}-{outliers1.sum()}")

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('fixed_acidity')
plt.ylabel('value')
plt.boxplot(new["fixed_acidity"])

fig2 = plt.figure(figsize =(2, 5))
plt.xlabel('volatile_acidity')
plt.ylabel('value')
plt.boxplot(new["volatile_acidity"])

fig3 = plt.figure(figsize =(2, 5))
plt.xlabel('citric_acid')
plt.ylabel('value')
plt.boxplot(new["citric_acid"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('residual_sugar')
plt.ylabel('value')
plt.boxplot(new["residual_sugar"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('chlorides')
plt.ylabel('value')
plt.boxplot(new["chlorides"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('free_sulfur_dioxide')
plt.ylabel('value')
plt.boxplot(new["free_sulfur_dioxide"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('total_sulfur_dioxide')
plt.ylabel('value')
plt.boxplot(new["total_sulfur_dioxide"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('density')
plt.ylabel('value')
plt.boxplot(new["density"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('pH')
plt.ylabel('value')
plt.boxplot(new["pH"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('sulphates')
plt.ylabel('value')
plt.boxplot(new["sulphates"])

fig1 = plt.figure(figsize =(2, 5))
plt.xlabel('alcohol')
plt.ylabel('value')
plt.boxplot(new["alcohol"])

plt.show()
# Out:
# /tmp/ipykernel_28715/324375944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns[column][outliers]=selected_columns[column].median()
# /tmp/ipykernel_28715/324375944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_columns[column][outliers]=selected_columns[column].median()
# /tmp/ipykernel_28715/324375944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
pearson1 = new.corrwith(new["fixed_acidity"], method="pearson")
spearman1 = new.corrwith(new["fixed_acidity"], method="spearman")

print("Pearson correlation with fixed_acidity")
print(pearson1)

print("Spearman correlation with fixed_acidity")
print(spearman1)
print("\n\n")




pearson2 = new.corrwith(new["volatile_acidity"], method="pearson")
spearman2 = new.corrwith(new["volatile_acidity"], method="spearman")

print("Pearson correlation with volatile_acidity")
print(pearson2)

print("Spearman correlation with volatile_acidity")
print(spearman2)
print("\n\n")


pearson3 = new.corrwith(new["citric_acid"], method="pearson")
spearman3 = new.corrwith(new["citric_acid"], method="spearman")

print("Pearson correlation with citric_acid")
print(pearson3)

print("Spearman correlation with citric_acid")
print(spearman3)
print("\n\n")


pearson4 = new.corrwith(new["residual_sugar"], method="pearson")
spearman4 = new.corrwith(new["residual_sugar"], method="spearman")

print("Pearson correlation with residual_sugar")
print(pearson4)

print("Spearman correlation with residual_sugar")
print(spearman4)
print("\n\n")


pearson41 = new.corrwith(new["chlorides"], method="pearson")
spearman41 = new.corrwith(new["chlorides"], method="spearman")

print("Pearson correlation with chlorides")
print(pearson41)

print("Spearman correlation with chlorides")
print(spearman41)
print("\n\n")

pearson42 = new.corrwith(new["free_sulfur_dioxide"], method="pearson")
spearman42 = new.corrwith(new["free_sulfur_dioxide"], method="spearman")

print("Pearson correlation with free_sulfur_dioxide")
print(pearson42)

print("Spearman correlation with free_sulfur_dioxide")
print(spearman42)
print("\n\n")

pearson43 = new.corrwith(new["total_sulfur_dioxide"], method="pearson")
spearman43 = new.corrwith(new["total_sulfur_dioxide"], method="spearman")

print("Pearson correlation with total_sulfur_dioxide")
print(pearson43)

print("Spearman correlation with total_sulfur_dioxide")
print(spearman43)
print("\n\n")


pearson44 = new.corrwith(new["density"], method="pearson")
spearman44 = new.corrwith(new["density"], method="spearman")

print("Pearson correlation with density")
print(pearson44)

print("Spearman correlation with density")
print(spearman44)
print("\n\n")


pearson45 = new.corrwith(new["pH"], method="pearson")
spearman45 = new.corrwith(new["pH"], method="spearman")

print("Pearson correlation with pH")
print(pearson45)

print("Spearman correlation with pH")
print(spearman45)
print("\n\n")


pearson46 = new.corrwith(new["sulphates"], method="pearson")
spearman46 = new.corrwith(new["sulphates"], method="spearman")

print("Pearson correlation with sulphates")
print(pearson46)

print("Spearman correlation with sulphates")
print(spearman46)
print("\n\n")


pearson47 = new.corrwith(new["alcohol"], method="pearson")
spearman47 = new.corrwith(new["alcohol"], method="spearman")

print("Pearson correlation with alcohol")
print(pearson47)

print("Spearman correlation with alcohol")
print(spearman47)
print("\n\n")


pearson48 = new.corrwith(new["quality"], method="pearson")
spearman48 = new.corrwith(new["quality"], method="spearman")

print("Pearson correlation with quality")
print(pearson48)

print("Spearman correlation with quality")
print(spearman48)
print("\n\n")
# Out:
# Pearson correlation with fixed_acidity
# fixed_acidity           1.000000
# volatile_acidity       -0.258476
# citric_acid             0.608682
# residual_sugar          0.225436
# chlorides               0.227814
# free_sulfur_dioxide    -0.145813
# total_sulfur_dioxide   -0.113789
# density                 0.557213
# pH                     -0.596539
# sulphates               0.176282
# alcohol                -0.048917
# quality                 0.120012
# dtype: float64
# Spearman correlation with fixed_acidity
# fixed_acidity           1.000000
# volatile_acidity       -0.266891
# citric_acid             0.615140
# residual_sugar          0.219427
# chlorides               0.230327
# free_sulfur_dioxide    -0.166544
# total_sulfur_dioxide   -0.088589
# density                 0.543315
# pH                     -0.638594
# sulphates               0.172917
# alcohol                -0.055657
# quality                 0.103534
# dtype: float64
#
#
#
# ...

# %%
pearson_corr = new.corr(method="pearson")
spearman_corr = new.corr(method="spearman")


print("Pearson Correlation")
print(pearson_corr)
print("\nSpearman Correlation")
print(spearman_corr)
# Out:
# Pearson Correlation
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000         -0.258476     0.608682
# volatile_acidity          -0.258476          1.000000    -0.564257
# citric_acid                0.608682         -0.564257     1.000000
# residual_sugar             0.225436          0.018550     0.156708
# chlorides                  0.227814          0.138565     0.091785
# free_sulfur_dioxide       -0.145813          0.004853    -0.060658
# total_sulfur_dioxide      -0.113789          0.090253    -0.010996
# density                    0.557213          0.000445     0.338521
# pH                        -0.596539          0.225681    -0.527095
# sulphates                  0.176282         -0.315552     0.277967
# alcohol                   -0.048917         -0.214283     0.129530
# quality                    0.120012         -0.349090     0.221375
#
#                       residual_sugar  chlorides  free_sulfur_dioxide  \
# ...

# %%
fig1 = plt.figure(figsize =(10, 20))
sns.heatmap(pearson_corr, annot=True, cmap="coolwarm")
plt.title("Pearson Correlation Heatmap")
plt.show()

# %%
fig1 = plt.figure(figsize =(10, 20))
sns.heatmap(spearman_corr, annot=True, cmap="coolwarm")
plt.title("Spearman Correlation Heatmap")
plt.show()

# %%
pearson_corr_copy = pearson_corr.copy()
for column in pearson_corr_copy.columns:
    for i in range(0,12):
        a = pearson_corr_copy[column][i]
        if (a == 1) | (a == -1):
            pearson_corr_copy[column][i] = "Perfect Correlation"
        if (a < 1 and a > 0.5) or (a < -0.5 and a > -1):
            pearson_corr_copy[column][i] = "Very Strong correlation"
        if (a <= 0.5 and a > 0.3) or (a < -0.3 and a >= -0.5):
            pearson_corr_copy[column][i] = "Strong correlation"
        if (a>0.1 and a<=0.3) or (a < -0.1 and a >= -0.3):
            pearson_corr_copy[column][i] = "Moderate correlation"
        if (a <= 0.1 and a > 0) or (a < 0 and a >= -0.1):
            pearson_corr_copy[column][i] = "Weak correlation"
        if (a == 0):
            pearson_corr_copy[column][i] = "No correlation"
print(pearson_corr_copy)
# Out:
#                                 fixed_acidity         volatile_acidity  \
# fixed_acidity             Perfect Correlation     Moderate correlation
# volatile_acidity         Moderate correlation      Perfect Correlation
# citric_acid           Very Strong correlation  Very Strong correlation
# residual_sugar           Moderate correlation         Weak correlation
# chlorides                Moderate correlation     Moderate correlation
# free_sulfur_dioxide      Moderate correlation         Weak correlation
# total_sulfur_dioxide     Moderate correlation         Weak correlation
# density               Very Strong correlation         Weak correlation
# pH                    Very Strong correlation     Moderate correlation
# sulphates                Moderate correlation       Strong correlation
# alcohol                      Weak correlation     Moderate correlation
# quality                  Moderate correlation       Strong correlation
#
# ...

# %%
spearman_corr_copy = spearman_corr.copy()
for column in spearman_corr_copy.columns:
    for i in range(0,12):
        a = spearman_corr_copy[column][i]
        if (a == 1) | (a == -1):
            spearman_corr_copy[column][i] = "Perfect Correlation"
        if (a < 1 and a > 0.5) or (a < -0.5 and a > -1):
            spearman_corr_copy[column][i] = "Very Strong correlation"
        if (a <= 0.5 and a > 0.3) or (a < -0.3 and a >= -0.5):
            spearman_corr_copy[column][i] = "Strong correlation"
        if (a>0.1 and a<=0.3) or (a < -0.1 and a >= -0.3):
            spearman_corr_copy[column][i] = "Moderate correlation"
        if (a <= 0.1 and a > 0) or (a < 0 and a >= -0.1):
            spearman_corr_copy[column][i] = "Weak correlation"
        if (a == 0):
            spearman_corr_copy[column][i] = "No correlation"
print(spearman_corr_copy)
# Out:
#                                 fixed_acidity         volatile_acidity  \
# fixed_acidity             Perfect Correlation     Moderate correlation
# volatile_acidity         Moderate correlation      Perfect Correlation
# citric_acid           Very Strong correlation  Very Strong correlation
# residual_sugar           Moderate correlation         Weak correlation
# chlorides                Moderate correlation     Moderate correlation
# free_sulfur_dioxide      Moderate correlation         Weak correlation
# total_sulfur_dioxide         Weak correlation         Weak correlation
# density               Very Strong correlation         Weak correlation
# pH                    Very Strong correlation     Moderate correlation
# sulphates                Moderate correlation       Strong correlation
# alcohol                      Weak correlation     Moderate correlation
# quality                  Moderate correlation       Strong correlation
#
# ...

# %%
pearson_corr1 = selected_columns.corrwith(selected_columns["quality"], method="pearson")
spearman_corr1 = selected_columns.corrwith(selected_columns["quality"], method="spearman")

# print(pearson_corr.)
pearson_corr2 = new.corrwith(new["quality"], method="pearson")
spearman_corr2 = new.corrwith(new["quality"], method="spearman")

plt.figure(figsize=(8, 5))
plt.bar(pearson_corr2.index, pearson_corr2.values)
plt.title("Pearson Correlation with 'quality' (New)")
plt.ylabel("Correlation Coefficient")
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(8, 5))
plt.bar(spearman_corr2.index, spearman_corr2.values)
plt.title("Spearman Correlation with 'quality' (New)")
plt.ylabel("Correlation Coefficient")
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(8, 5))
plt.bar(pearson_corr1.index, pearson_corr1.values)
plt.title("Pearson Correlation with 'quality' (Old)")
plt.ylabel("Correlation Coefficient")
plt.xticks(rotation=45)
plt.show()


plt.figure(figsize=(8, 5))
plt.bar(spearman_corr1.index, spearman_corr1.values)
plt.title("Spearman Correlation with 'quality' (Old)")
plt.ylabel("Correlation Coefficient")
plt.xticks(rotation=45)
plt.show()

# %%
plt.title("Pearson Correlation with 'quality' (New)")
plt.scatter(pearson_corr2.index,pearson_corr2.values)
plt.xlabel("Index of pearson correlation")
plt.ylabel("Value of pearson correlation")
plt.xticks(rotation=45)
plt.show()

plt.title("Spearman Correlation with 'quality' (New)")
plt.scatter(spearman_corr2.index,spearman_corr2.values)
plt.xlabel("Index of Spearman correlation")
plt.ylabel("Value of Spearman correlation")
plt.xticks(rotation=45)
plt.show()


plt.title("Pearson Correlation with 'quality' (Old)")
plt.scatter(pearson_corr1.index,pearson_corr1.values)
plt.xlabel("Index of pearson correlation")
plt.ylabel("Value of pearson correlation")
plt.xticks(rotation=45)
plt.show()


plt.title("Spearman Correlation with 'quality' (Old)")
plt.scatter(spearman_corr1.index,spearman_corr1.values)
plt.xlabel("Index of Spearman correlation")
plt.ylabel("Value of Spearman correlation")
plt.xticks(rotation=45)
plt.show()

# %%
print(f"Minimum of new data:\n{new.min()}\n\n")
print(f"Maximum of new data:\n{new.max()}\n\n")

# print(f"Range: {new.min()} - {new.max()}\n\n")
# Out:
# Minimum of new data:
# fixed_acidity           4.60000
# volatile_acidity        0.12000
# citric_acid             0.00000
# residual_sugar          0.90000
# chlorides               0.04100
# free_sulfur_dioxide     1.00000
# total_sulfur_dioxide    6.00000
# density                 0.99235
# pH                      2.93000
# sulphates               0.33000
# alcohol                 8.40000
# quality                 4.00000
# dtype: float64
#
#
# Maximum of new data:
# fixed_acidity            12.300
# volatile_acidity          1.010
# citric_acid               0.790
# residual_sugar            3.650
# chlorides                 0.119
# free_sulfur_dioxide      42.000
# total_sulfur_dioxide    122.000
# density                   1.001
# pH                        3.680
# sulphates                 0.990
# alcohol                  13.500
# quality                   7.000
# dtype: float64

# %%
new31 = new.copy()
for column in new31.columns:
    min_temp = new31[column].min()
    max_temp = new31[column].max()
    new31[column] = (((new31[column] - min_temp)/(max_temp - min_temp))*(20-0) ) + 0

print("Min max noramlization: 0-20")
print(new3)
# Out:
# Min max noramlization: 0-20
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0          7.272727         13.033708     0.000000        7.272727   8.974359
# 1          8.311688         17.078652     0.000000       12.363636  14.615385
# 2          8.311688         14.382022     1.012658       10.181818  13.076923
# 3         17.142857          3.595506    14.177215        7.272727   8.717949
# 4          7.272727         13.033708     0.000000        7.272727   8.974359
# ...             ...               ...          ...             ...        ...
# 1594       6.200000          0.600000     0.080000        2.000000   0.090000
# 1595       5.900000          0.550000     0.100000        2.200000   0.062000
# 1596       6.300000          0.510000     0.130000        2.300000   0.076000
# 1597       5.900000          0.645000     0.120000        2.000000   0.075000
# 1598       6.000000          0.310000     0.470000        3.600000   0.067000
#
# ...

# %%
new4 = new.copy()
for column in new4.columns:
    mean_temp = new4[column].mean()
    std_temp = new4[column].std()
    new4[column] = (new4[column] - mean_temp)/(std_temp)
print("Standardize: \n")
print(new4)

print("New Mean")
print(new4.mean())

print("New standard deviation")
print(new4.std())


pearson_corr3 = new.corr(method="pearson")
spearman_corr3 = new.corr(method="spearman")

print("\n\n\nPearson Correlation (without standardization)")
print(pearson_corr3)
print("\n\nSpearman Correlation (without standardization)")
print(spearman_corr3)

pearson_corr5 = new4.corr(method="pearson")
spearman_corr5 = new4.corr(method="spearman")


print("\n\n\nPearson Correlation (with standardization)")
print(pearson_corr5)
print("\n\nSpeelation  (with standardization)")
print(spearman_corr5)
# Out:
# Standardize:
#
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0         -0.506099          1.083733    -1.394790       -0.660195  -0.193443
# 1         -0.237801          2.170770    -1.394790        0.979744   1.341272
# 2         -0.237801          1.446079    -1.188546        0.276913   0.922713
# 3          2.042727         -1.452688     1.492623       -0.660195  -0.263202
# 4         -0.506099          1.083733    -1.394790       -0.660195  -0.193443
# ...             ...               ...          ...             ...        ...
# 1594      -1.310991          0.479823    -0.982302       -0.425918   0.783194
# 1595      -1.512214          0.177868    -0.879180        0.042636  -1.170079
# 1596      -1.243917         -0.063696    -0.724497        0.276913  -0.193443
# 1597      -1.512214          0.751582    -0.776058       -0.425918  -0.263202
# 1598      -1.445140         -1.271515     1.028575        3.322514  -0.821280
#
# ...

# %%
col = new.columns
data_minmax = new.copy()
scaler_minmax = MinMaxScaler(feature_range=(0, 1))
data_minmax[col] = scaler_minmax.fit_transform(new[col])
print("Min-Max Normalized Data (Range 0-1) using Scikit-learn:")
print(data_minmax)
# Out:
# Min-Max Normalized Data (Range 0-1) using Scikit-learn:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0          0.363636          0.651685     0.000000        0.363636   0.448718
# 1          0.415584          0.853933     0.000000        0.618182   0.730769
# 2          0.415584          0.719101     0.050633        0.509091   0.653846
# 3          0.857143          0.179775     0.708861        0.363636   0.435897
# 4          0.363636          0.651685     0.000000        0.363636   0.448718
# ...             ...               ...          ...             ...        ...
# 1594       0.207792          0.539326     0.101266        0.400000   0.628205
# 1595       0.168831          0.483146     0.126582        0.472727   0.269231
# 1596       0.220779          0.438202     0.164557        0.509091   0.448718
# 1597       0.168831          0.589888     0.151899        0.400000   0.435897
# ...

# %%
col = new.columns
data_minmax2 = new.copy()
scaler_minmax2 = MinMaxScaler(feature_range=(0, 20))
data_minmax2[col] = scaler_minmax2.fit_transform(new[col])
print("Min-Max Normalized Data (Range 0-20) using Scikit-learn:")
print(data_minmax2)
# Out:
# Min-Max Normalized Data (Range 0-20) using Scikit-learn:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0          7.272727         13.033708     0.000000        7.272727   8.974359
# 1          8.311688         17.078652     0.000000       12.363636  14.615385
# 2          8.311688         14.382022     1.012658       10.181818  13.076923
# 3         17.142857          3.595506    14.177215        7.272727   8.717949
# 4          7.272727         13.033708     0.000000        7.272727   8.974359
# ...             ...               ...          ...             ...        ...
# 1594       4.155844         10.786517     2.025316        8.000000  12.564103
# 1595       3.376623          9.662921     2.531646        9.454545   5.384615
# 1596       4.415584          8.764045     3.291139       10.181818   8.974359
# 1597       3.376623         11.797753     3.037975        8.000000   8.717949
# ...
